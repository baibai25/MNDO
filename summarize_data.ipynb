# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sm = pd.read_csv('result/data/sm.csv', index_col=0)
b1 = pd.read_csv('result/data/b1.csv', index_col=0)
b2 = pd.read_csv('result/data/b2.csv', index_col=0)
ada = pd.read_csv('result/data/ada.csv', index_col=0)
enn = pd.read_csv('result/data/enn.csv', index_col=0)
tom = pd.read_csv('result/data/tom.csv', index_col=0)
mnd = pd.read_csv('result/data/mnd.csv', index_col=0)

# %%
desc_sm = sm.describe()
desc_sm = desc_sm.loc['mean':'std']
desc_b1 = b1.describe()
desc_b1 = desc_b1.loc['mean':'std']
desc_b2 = b2.describe()
desc_b2 = desc_b2.loc['mean':'std']
desc_ada = ada.describe()
desc_ada = desc_ada.loc['mean':'std']
desc_enn = enn.describe()
desc_enn = desc_enn.loc['mean':'std']
desc_tom = tom.describe()
desc_tom = desc_tom.loc['mean':'std']
desc_mnd = mnd.describe()
desc_mnd = desc_mnd.loc['mean':'std']
desc_list = [desc_sm, desc_b1, desc_b2, desc_ada, desc_enn, desc_tom, desc_mnd]

# %%
metrics = ['Sensitivity', 'Specificity', 'Geometric mean', 'AUC']
col = ['SMOTE', 'Borderline1', 'Borderline2', 'ADASYN', 'SMOTEENN', 'SMOTETomek', 'MNDO']

# %%
# 各osの統計量をまとめる
svm = pd.DataFrame(index=[], columns=metrics)
for i in range(len(desc_list)):
    tmp = desc_list[i][desc_list[i].columns[0:4]]
    svm = pd.concat([svm, tmp])
    
# 形式を論文用に変更
df = pd.DataFrame(index=[], columns=col)
mean = svm.loc['mean'].T
mean.columns = col
std = svm.loc['std'].T
std.columns = col

for i in range(len(mean.index)):
    df = pd.concat([df, mean.iloc[[i]]])
    df = pd.concat([df, std.iloc[[i]]])
statics = ['Mean', 'Std'] * int(len(df.index)/2)
df['Statics'] = statics
df = df.set_index([df.index, 'Statics'])
df.to_csv('result/summary/svm.csv')

# %%
# 各osの統計量をまとめる
svm = pd.DataFrame(index=[], columns=metrics)
for i in range(len(desc_list)):
    tmp = desc_list[i][desc_list[i].columns[0:4]]
    svm = pd.concat([svm, tmp])
    
# 形式を論文用に変更
df = pd.DataFrame(index=[], columns=col)
mean = svm.loc['mean'].T
mean.columns = col
std = svm.loc['std'].T
std.columns = col

for i in range(len(mean.index)):
    df = pd.concat([df, mean.iloc[[i]]])
    df = pd.concat([df, std.iloc[[i]]])
statics = ['Mean', 'Std'] * int(len(df.index)/2)
df['Statics'] = statics
df = df.set_index([df.index, 'Statics'])
df.to_csv('result/summary/tree.csv')

# %%
df
# Out:
#                               SMOTE Borderline1 Borderline2     ADASYN  \
#                  Statics
# AUC              Mean           NaN         NaN         NaN        NaN
#                  Std            NaN         NaN         NaN        NaN
# AUC.1            Mean       0.73897    0.745183    0.698748   0.755071
#                  Std        0.16921    0.178001    0.171609   0.168655
# Geometric mean   Mean           NaN         NaN         NaN        NaN
#                  Std            NaN         NaN         NaN        NaN
# Geometric mean.1 Mean      0.659055    0.649797    0.593969   0.682531
#                  Std       0.275809    0.309491    0.302432   0.276177
# Sensitivity      Mean           NaN         NaN         NaN        NaN
#                  Std            NaN         NaN         NaN        NaN
# Sensitivity.1    Mean      0.540889    0.544766    0.485162    0.57439
#                  Std       0.327503    0.350265    0.335379    0.32331
# Specificity      Mean           NaN         NaN         NaN        NaN
#                  Std            NaN         NaN         NaN        NaN
# Specificity.1    Mean       0.93705      0.9456    0.912333   0.935752
#                  Std      0.0625752   0.0562196   0.0823269  0.0612054
#
#                            SMOTEENN SMOTETomek      MNDO
#                  Statics
# AUC              Mean           NaN        NaN       NaN
#                  Std            NaN        NaN       NaN
# AUC.1            Mean      0.772329   0.744031  0.624177
#                  Std       0.167488   0.168648  0.195247
# Geometric mean   Mean           NaN        NaN       NaN
#                  Std            NaN        NaN       NaN
# Geometric mean.1 Mean      0.725697   0.669239  0.428832
#                  Std       0.250561   0.272759  0.364611
# Sensitivity      Mean           NaN        NaN       NaN
#                  Std            NaN        NaN       NaN
# Sensitivity.1    Mean      0.645517   0.553829  0.481734
#                  Std       0.300577   0.321731  0.397217
# Specificity      Mean           NaN        NaN       NaN
#                  Std            NaN        NaN       NaN
# Specificity.1    Mean      0.899141   0.934233  0.766619
#                  Std      0.0817223  0.0645928  0.330757
